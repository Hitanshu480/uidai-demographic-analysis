# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# enrollment-1 file

# %%
a=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_enrolment\\api_data_aadhar_enrolment\\api_data_aadhar_enrolment_0_500000.csv")
a.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
a.shape
# Out:
# (500000, 7)

# %%
a['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'The Dadra And Nagar Haveli And Daman And Diu',
#        'Arunachal Pradesh', 'Himachal Pradesh', 'Goa',
#        'Jammu And Kashmir', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Orissa', 'Pondicherry',
#        'Puducherry', 'Lakshadweep', 'Andaman & Nicobar Islands',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman and Diu',
#        'WEST BENGAL', 'Jammu & Kashmir', 'West  Bengal', '100000',
#        'Daman & Diu', 'West Bangal', 'Westbengal', 'West bengal',
# ...

# %%
a['new_date'] = pd.to_datetime(a['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
a
# Out:
#               date           state          district  pincode  age_0_5  \
# 0       02-03-2025       Meghalaya  East Khasi Hills   793121       11
# 1       09-03-2025       Karnataka   Bengaluru Urban   560043       14
# 2       09-03-2025   Uttar Pradesh      Kanpur Nagar   208001       29
# 3       09-03-2025   Uttar Pradesh           Aligarh   202133       62
# 4       09-03-2025       Karnataka   Bengaluru Urban   560016       14
# ...            ...             ...               ...      ...      ...
# 499995  26-10-2025  Andhra Pradesh       Mahbubnagar   509207        1
# 499996  26-10-2025  Andhra Pradesh             Medak   502220        1
# 499997  26-10-2025  Andhra Pradesh             Medak   502256        0
# 499998  26-10-2025  Andhra Pradesh             Medak   502286        1
# 499999  26-10-2025  Andhra Pradesh           N. T. R   521402        1
#
#         age_5_17  age_18_greater  new_date
# 0             61              37  20250302
# ...

# %%
a['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(a['new_date'].max())
print(a['new_date'].min())
# Out:
# 20251026
# 20250302

# %% [markdown]
# Enrollment file-2

# %%
b=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_enrolment\\api_data_aadhar_enrolment\\api_data_aadhar_enrolment_500000_1000000.csv")
b.head()
# Out:
#          date           state  district  pincode  age_0_5  age_5_17  \
# 0  26-10-2025  Andhra Pradesh  Nalgonda   508004        0         1
# 1  26-10-2025  Andhra Pradesh  Nalgonda   508238        1         0
# 2  26-10-2025  Andhra Pradesh  Nalgonda   508278        1         0
# 3  26-10-2025  Andhra Pradesh   Nandyal   518432        0         1
# 4  26-10-2025  Andhra Pradesh   Nandyal   518543        1         0
#
#    age_18_greater
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
b.shape
# Out:
# (500000, 7)

# %%
b['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'West Bengal',
#        'Chhattisgarh', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Bihar', 'Chandigarh', 'Sikkim', 'West Bangal',
#        'Dadra and Nagar Haveli', 'Daman and Diu',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Jammu & Kashmir',
#        'andhra pradesh', 'Dadra & Nagar Haveli', 'Westbengal',
#        'Daman & Diu', 'WESTBENGAL', 'West bengal', 'West  Bengal',
#        'WEST BENGAL', '100000'], dtype=object)

# %%
b['new_date'] = pd.to_datetime(b['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
b
# Out:
#             date        state        district  pincode  age_0_5  age_5_17  \
# 0     31-12-2025    Karnataka           Bidar   585330        2         3
# 1     31-12-2025    Karnataka           Bidar   585402        6         0
# 2     31-12-2025    Karnataka           Bidar   585413        1         0
# 3     31-12-2025    Karnataka           Bidar   585418        1         2
# 4     31-12-2025    Karnataka           Bidar   585421        4         3
# ...          ...          ...             ...      ...      ...       ...
# 6024  31-12-2025  West Bengal  West Midnapore   721149        2         0
# 6025  31-12-2025  West Bengal  West Midnapore   721150        2         2
# 6026  31-12-2025  West Bengal  West Midnapore   721305        0         1
# 6027  31-12-2025  West Bengal  West Midnapore   721504        1         0
# 6028  31-12-2025  West Bengal  West Midnapore   721517        2         1
#
#       age_18_greater  new_date
# 0                  0  20251231
# ...

# %%
b['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(b['new_date'].max())
print(b['new_date'].min())
# Out:
# 20251231
# 20251231

# %% [markdown]
# Enrollment file-3

# %%
c=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_enrolment\\api_data_aadhar_enrolment\\api_data_aadhar_enrolment_1000000_1006029.csv")
c.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater
# 0  31-12-2025  Karnataka    Bidar   585330        2         3               0
# 1  31-12-2025  Karnataka    Bidar   585402        6         0               0
# 2  31-12-2025  Karnataka    Bidar   585413        1         0               0
# 3  31-12-2025  Karnataka    Bidar   585418        1         2               0
# 4  31-12-2025  Karnataka    Bidar   585421        4         3               0

# %%
c.shape
# Out:
# (6029, 7)

# %%
c['state'].unique()
# Out:
# array(['Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Orissa', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Daman and Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Pondicherry'], dtype=object)

# %%
c['new_date'] = pd.to_datetime(c['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
c
# Out:
#             date        state        district  pincode  age_0_5  age_5_17  \
# 0     31-12-2025    Karnataka           Bidar   585330        2         3
# 1     31-12-2025    Karnataka           Bidar   585402        6         0
# 2     31-12-2025    Karnataka           Bidar   585413        1         0
# 3     31-12-2025    Karnataka           Bidar   585418        1         2
# 4     31-12-2025    Karnataka           Bidar   585421        4         3
# ...          ...          ...             ...      ...      ...       ...
# 6024  31-12-2025  West Bengal  West Midnapore   721149        2         0
# 6025  31-12-2025  West Bengal  West Midnapore   721150        2         2
# 6026  31-12-2025  West Bengal  West Midnapore   721305        0         1
# 6027  31-12-2025  West Bengal  West Midnapore   721504        1         0
# 6028  31-12-2025  West Bengal  West Midnapore   721517        2         1
#
#       age_18_greater  new_date
# 0                  0  20251231
# ...

# %%
c['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(c['new_date'].max())
print(c['new_date'].min())
# Out:
# 20251231
# 20251231

# %%
df = pd.concat([a,b ,c ], axis=0, ignore_index=True)
df.shape
# Out:
# (512058, 8)

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater  new_date
# 0              37  20250302
# 1              39  20250309
# 2              12  20250309
# 3              15  20250309
# 4              21  20250309

# %%
df['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['state'].nunique()
# Out:
# 54

# %%
import pandas as pd
import re

def clean_state_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove symbols like &, .
    x = re.sub(r'\s+', ' ', x).strip()  # remove extra spaces
    return x

# %%
state_mapping = {
    # West Bengal
    'west bengal': 'West Bengal',
    'west bangal': 'West Bengal',
    'westbengal': 'West Bengal',
    'west  bengal': 'West Bengal',
    'westbengal ': 'West Bengal',

    # Andhra Pradesh
    'andhra pradesh': 'Andhra Pradesh',

    # Odisha
    'odisha': 'Odisha',
    'orissa': 'Odisha',

    # Jammu & Kashmir
    'jammu and kashmir': 'Jammu and Kashmir',
    'jammu kashmir': 'Jammu and Kashmir',

    # Collapse all Dadra / Daman variants into ONE state
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'the dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman diu': 'Dadra and Nagar Haveli and Daman and Diu',


    # Puducherry
    'puducherry': 'Puducherry',


    # Andaman & Nicobar Islands
    'andaman and nicobar islands': 'Andaman and Nicobar Islands',
    'andaman nicobar islands': 'Andaman and Nicobar Islands',

    # Puducherry
    'pondicherry': 'Puducherry',

    # Case-normalized direct matches
    'delhi': 'Delhi',
    'ladakh': 'Ladakh',
    'goa': 'Goa',
    'sikkim': 'Sikkim',
    'assam': 'Assam',
    'bihar': 'Bihar',
    'punjab': 'Punjab',
    'kerala': 'Kerala',
    'haryana': 'Haryana',
    'gujarat': 'Gujarat',
    'tamil nadu': 'Tamil Nadu',
    'telangana': 'Telangana',
    'karnataka': 'Karnataka',
    'maharashtra': 'Maharashtra',
    'rajasthan': 'Rajasthan',
    'uttar pradesh': 'Uttar Pradesh',
    'madhya pradesh': 'Madhya Pradesh',
    'himachal pradesh': 'Himachal Pradesh',
    'arunachal pradesh': 'Arunachal Pradesh',
    'chhattisgarh': 'Chhattisgarh',
    'jharkhand': 'Jharkhand',
    'manipur': 'Manipur',
    'meghalaya': 'Meghalaya',
    'mizoram': 'Mizoram',
    'nagaland': 'Nagaland',
    'tripura': 'Tripura',
    'uttarakhand': 'Uttarakhand',
    'lakshadweep': 'Lakshadweep',
    'chandigarh': 'Chandigarh'
}

# %%
df['state_clean'] = (
    df['state']
    .apply(clean_state_name)
    .map(state_mapping)
)

# %%
# Drop invalid entries like numeric junk
df = df[~df['state'].astype(str).str.isnumeric()]

# Optional: check unmapped states
unmapped = df[df['state_clean'].isna()]['state'].unique()
print("Unmapped values:", unmapped)
# Out:
# Unmapped values: []

# %%
df['state_clean'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Arunachal Pradesh',
#        'Himachal Pradesh', 'Goa', 'Ladakh', 'Andaman and Nicobar Islands',
#        'Puducherry', 'Lakshadweep'], dtype=object)

# %%
df['state_clean'].nunique()
# Out:
# 36

# %%
df.dtypes
# Out:
# date              object
# state             object
# district          object
# pincode            int64
# age_0_5            int64
# age_5_17           int64
# age_18_greater     int64
# new_date          object
# state_clean       object
# dtype: object

# %%
df_odisha=df[df['state_clean']=='Odisha']
df_odisha
# Out:
#               date   state      district  pincode  age_0_5  age_5_17  \
# 964     01-04-2025  Odisha  Nabarangapur   764076      182        82
# 2175    01-07-2025  Odisha       Khordha   751024       37        37
# 2348    01-07-2025  Odisha   Nabarangpur   764074      327       103
# 4926    01-09-2025  Odisha         Angul   759022        2         0
# 4927    01-09-2025  Odisha         Angul   759100        1         1
# ...            ...     ...           ...      ...      ...       ...
# 510653  31-12-2025  Orissa    Kendrapara   754222        0         1
# 510654  31-12-2025  Orissa     Kendujhar   758078        1         0
# 510655  31-12-2025  Orissa       Khordha   751001        1         0
# 510656  31-12-2025  Orissa       Khordha   751006        1         0
# 510657  31-12-2025  Orissa      Rayagada   765001        0         1
#
#         age_18_greater  new_date state_clean
# 964                 12  20250401      Odisha
# 2175                13  20250701      Odisha
# ...

# %%
df_odisha['district'].unique()
# Out:
# array(['Nabarangapur', 'Khordha', 'Nabarangpur', 'Angul', 'Anugul',
#        'Balangir', 'Baleswar', 'Bargarh', 'Baudh', 'Bhadrak', 'Boudh',
#        'Cuttack', 'Debagarh', 'Dhenkanal', 'Gajapati', 'Ganjam', 'JAJPUR',
#        'Jagatsinghapur', 'Jagatsinghpur', 'Jajapur', 'Kalahandi',
#        'Kandhamal', 'Kendrapara', 'Kendujhar', 'Khorda', 'Koraput',
#        'Malkangiri', 'Mayurbhanj', 'Nayagarh', 'Nuapada', 'Puri',
#        'Rayagada', 'Sambalpur', 'Sonapur', 'Subarnapur', 'Sundargarh',
#        'Sundergarh', 'Baleshwar', 'Jharsuguda', 'NUAPADA', 'ANUGUL',
#        'jajpur', 'Jajpur'], dtype=object)

# %%
import re
import pandas as pd

def clean_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove (), ., etc
    x = re.sub(r'\s+', ' ', x).strip()
    return x

# %%
district_mapping_odisha = {

    # Angul
    'angul': 'Angul',
    'anugul': 'Angul',
    'anugal': 'Angul',
    'anugul ': 'Angul',
    'anugul*': 'Angul',
    'anugul  *': 'Angul',

    # Balangir
    'balangir': 'Balangir',
    'bolangir': 'Balangir',

    # Baleswar (Balasore)
    'baleswar': 'Baleswar',
    'baleshwar': 'Baleswar',
    'balasore': 'Baleswar',

    # Bargarh
    'bargarh': 'Bargarh',

    # Bhadrak
    'bhadrak': 'Bhadrak',

    # Boudh
    'boudh': 'Boudh',
    'baudh': 'Boudh',

    # Cuttack
    'cuttack': 'Cuttack',

    # Debagarh
    'debagarh': 'Debagarh',
    'deogarh': 'Debagarh',

    # Dhenkanal
    'dhenkanal': 'Dhenkanal',

    # Gajapati
    'gajapati': 'Gajapati',

    # Ganjam
    'ganjam': 'Ganjam',

    # Jagatsinghapur
    'jagatsinghapur': 'Jagatsinghapur',
    'jagatsinghpur': 'Jagatsinghapur',

    # Jajpur
    'jajapur': 'Jajpur',
    'jajpur': 'Jajpur',
    'jajpur ': 'Jajpur',

    # Jharsuguda
    'jharsuguda': 'Jharsuguda',

    # Kalahandi
    'kalahandi': 'Kalahandi',

    # Kandhamal
    'kandhamal': 'Kandhamal',
    'phulbani': 'Kandhamal',

    # Kendrapara
    'kendrapara': 'Kendrapara',

    # Kendujhar (Keonjhar)
    'kendujhar': 'Kendujhar',
    'keonjhar': 'Kendujhar',

    # Khordha
    'khorda': 'Khordha',
    'khordha': 'Khordha',
    'khordha  *': 'Khordha',

    # Koraput
    'koraput': 'Koraput',

    # Malkangiri
    'malkangiri': 'Malkangiri',

    # Mayurbhanj
    'mayurbhanj': 'Mayurbhanj',

    # Nabarangapur
    'nabarangapur': 'Nabarangapur',
    'nabarangpur': 'Nabarangapur',

    # Nayagarh
    'nayagarh': 'Nayagarh',

    # Nuapada
    'nuapada': 'Nuapada',

    # Puri
    'puri': 'Puri',

    # Rayagada
    'rayagada': 'Rayagada',

    # Sambalpur
    'sambalpur': 'Sambalpur',

    # Subarnapur (Sonapur)
    'sonapur': 'Subarnapur',
    'subarnapur': 'Subarnapur',

    # Sundargarh
    'sundergarh': 'Sundargarh',
    'sundargarh': 'Sundargarh',
}

# %%
df_odisha = df_odisha.copy()

# %%
df_odisha.loc[:, 'district_clean'] = (
    df_odisha['district']
    .apply(clean_name)
    .map(district_mapping_odisha)
    .fillna(df_odisha['district'])
)

# %%
df_odisha['district_clean'].unique()
# Out:
# array(['Nabarangapur', 'Khordha', 'Angul', 'Balangir', 'Baleswar',
#        'Bargarh', 'Boudh', 'Bhadrak', 'Cuttack', 'Debagarh', 'Dhenkanal',
#        'Gajapati', 'Ganjam', 'Jajpur', 'Jagatsinghapur', 'Kalahandi',
#        'Kandhamal', 'Kendrapara', 'Kendujhar', 'Koraput', 'Malkangiri',
#        'Mayurbhanj', 'Nayagarh', 'Nuapada', 'Puri', 'Rayagada',
#        'Sambalpur', 'Subarnapur', 'Sundargarh', 'Jharsuguda'],
#       dtype=object)

# %%
df_odisha['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_odisha['pincode'].nunique()
# Out:
# 905

# %%
pincode_check=df_odisha.groupby('district_clean')['pincode'].nunique().reset_index(name='unique_pincode_count')

# %%
pincode_check
# Out:
#     district_clean  unique_pincode_count
# 0            Angul                    27
# 1         Balangir                    29
# 2         Baleswar                    57
# 3          Bargarh                    26
# 4          Bhadrak                    41
# 5            Boudh                    13
# 6          Cuttack                    69
# 7         Debagarh                     6
# 8        Dhenkanal                    22
# 9         Gajapati                    16
# 10          Ganjam                    78
# 11  Jagatsinghapur                    31
# 12          Jajpur                    42
# 13      Jharsuguda                    19
# 14       Kalahandi                    26
# 15       Kandhamal                    27
# 16      Kendrapara                    43
# 17       Kendujhar                    44
# 18         Khordha                    65
# 19         Koraput                    33
# 20      Malkangiri                    11
# 21      Mayurbhanj                    69
# ...

# %%
df_odisha[df_odisha['district_clean']=='Baleswar']['pincode'].unique()
# Out:
# array([756001, 756003, 756029, 756037, 756039, 756044, 756058, 756041,
#        756081, 756024, 756032, 756047, 756115, 756134, 756021, 756023,
#        756049, 756085, 756002, 756027, 756045, 756083, 756019, 756020,
#        756030, 756046, 756055, 756080, 756035, 756026, 756033, 756040,
#        756048, 756079, 756126, 756182, 756060, 756022, 756025, 756028,
#        756034, 756036, 756038, 756042, 756043, 756059, 756056, 757017,
#        756166, 757082, 756053, 756168, 756051, 756018, 756084, 757055,
#        756086])

# %%
pin_district_count = (
    df_odisha.groupby('pincode')['district_clean']
      .nunique()
      .reset_index(name='district_count')
)

# %%
pin_district_count
# Out:
#      pincode  district_count
# 0     751001               1
# 1     751002               2
# 2     751003               1
# 3     751004               1
# 4     751005               1
# ..       ...             ...
# 900   770072               1
# 901   770073               1
# 902   770074               1
# 903   770075               1
# 904   770076               1
#
# [905 rows x 2 columns]

# %%
problem_pins = pin_district_count[
    pin_district_count['district_count'] > 1
]

# %%
problem_pins
# Out:
#      pincode  district_count
# 1     751002               2
# 39    752019               2
# 40    752020               2
# 43    752023               2
# 48    752030               2
# ..       ...             ...
# 815   768109               2
# 829   768212               2
# 831   768214               2
# 838   768221               2
# 844   768228               2
#
# [85 rows x 2 columns]

# %%
df_flagged = df_odisha.merge(
    problem_pins[['pincode']],
    on='pincode',
    how='inner'
)

# %%
df_flagged
# Out:
#             date   state    district  pincode  age_0_5  age_5_17  \
# 0     01-09-2025  Odisha       Angul   759022        2         0
# 1     01-09-2025  Odisha     Cuttack   754001        1         1
# 2     01-09-2025  Odisha     Cuttack   754100        0         1
# 3     01-09-2025  Odisha     Cuttack   754204        3         0
# 4     01-09-2025  Odisha     Cuttack   754209        3         0
# ...          ...     ...         ...      ...      ...       ...
# 3378  31-12-2025  Odisha      Khorda   752060        0         1
# 3379  31-12-2025  Odisha      Khorda   752114        1         0
# 3380  31-12-2025  Odisha  Mayurbhanj   757055        1         3
# 3381  31-12-2025  Odisha  Mayurbhanj   757082        1         1
# 3382  31-12-2025  Odisha   Sambalpur   768212        0         1
#
#       age_18_greater  new_date state_clean district_clean
# 0                  0  20250901      Odisha          Angul
# 1                  0  20250901      Odisha        Cuttack
# ...

# %%
flagged_pincode_dominant=df_flagged.groupby(['district_clean', 'pincode'])[['age_0_5','age_5_17','age_18_greater']].sum().reset_index()

# %%
flagged_pincode_dominant['total_enroll']=flagged_pincode_dominant['age_0_5']+flagged_pincode_dominant['age_5_17']+flagged_pincode_dominant['age_18_greater']
flagged_pincode_dominant.sort_values('pincode')
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  total_enroll
# 110        Khordha   751002       91        16               0           107
# 149           Puri   751002        3         0               0             3
# 150           Puri   752019       51         4               0            55
# 111        Khordha   752019       25         4               0            29
# 112        Khordha   752020       58         7               0            65
# ..             ...      ...      ...       ...             ...           ...
# 166      Sambalpur   768214       17         1               0            18
# 167      Sambalpur   768221       39         9               0            48
# 85      Jharsuguda   768221       26         0               0            26
# 15         Bargarh   768228        1         0               0             1
# 168      Sambalpur   768228       72        15               0            87
#
# [172 rows x 6 columns]

# %%
idx = flagged_pincode_dominant.groupby('pincode')['total_enroll'].idxmax()
df_filtered = flagged_pincode_dominant.loc[idx]
df_filtered
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  total_enroll
# 110        Khordha   751002       91        16               0           107
# 150           Puri   752019       51         4               0            55
# 112        Khordha   752020       58         7               0            65
# 113        Khordha   752023       43         7               0            50
# 114        Khordha   752030       50         9               0            59
# ..             ...      ...      ...       ...             ...           ...
# 48        Debagarh   768109      101        17               2           120
# 165      Sambalpur   768212       62         7               0            69
# 166      Sambalpur   768214       17         1               0            18
# 167      Sambalpur   768221       39         9               0            48
# 168      Sambalpur   768228       72        15               0            87
#
# [85 rows x 6 columns]

# %%
df_odisha['pin_multi_district_flag'] = (
    df_odisha.groupby('pincode')['district']
      .transform('nunique') > 1
)

# %%
pin_district_map = (
    df_odisha[df_odisha['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']
    .unique()
    .reset_index()
)

# %%
file_path='pin_district_map.xlsx'
pin_district_map.to_excel(file_path, index=False)

# %%
df_odisha['pin_multi_district_flag'].value_counts()
# Out:
# pin_multi_district_flag
# False    15753
# True      9572
# Name: count, dtype: int64

# %%
df_odisha['total_enroll']=df_odisha['age_0_5']+df_odisha['age_5_17']+df_odisha['age_18_greater']
df_odisha
# Out:
#               date   state      district  pincode  age_0_5  age_5_17  \
# 964     01-04-2025  Odisha  Nabarangapur   764076      182        82
# 2175    01-07-2025  Odisha       Khordha   751024       37        37
# 2348    01-07-2025  Odisha   Nabarangpur   764074      327       103
# 4926    01-09-2025  Odisha         Angul   759022        2         0
# 4927    01-09-2025  Odisha         Angul   759100        1         1
# ...            ...     ...           ...      ...      ...       ...
# 510653  31-12-2025  Orissa    Kendrapara   754222        0         1
# 510654  31-12-2025  Orissa     Kendujhar   758078        1         0
# 510655  31-12-2025  Orissa       Khordha   751001        1         0
# 510656  31-12-2025  Orissa       Khordha   751006        1         0
# 510657  31-12-2025  Orissa      Rayagada   765001        0         1
#
#         age_18_greater  new_date state_clean district_clean  \
# 964                 12  20250401      Odisha   Nabarangapur
# ...

# %%
df_odisha['month']=df_odisha['new_date'].astype(str).str[4:6]
df_odisha
# Out:
#               date   state      district  pincode  age_0_5  age_5_17  \
# 964     01-04-2025  Odisha  Nabarangapur   764076      182        82
# 2175    01-07-2025  Odisha       Khordha   751024       37        37
# 2348    01-07-2025  Odisha   Nabarangpur   764074      327       103
# 4926    01-09-2025  Odisha         Angul   759022        2         0
# 4927    01-09-2025  Odisha         Angul   759100        1         1
# ...            ...     ...           ...      ...      ...       ...
# 510653  31-12-2025  Orissa    Kendrapara   754222        0         1
# 510654  31-12-2025  Orissa     Kendujhar   758078        1         0
# 510655  31-12-2025  Orissa       Khordha   751001        1         0
# 510656  31-12-2025  Orissa       Khordha   751006        1         0
# 510657  31-12-2025  Orissa      Rayagada   765001        0         1
#
#         age_18_greater  new_date state_clean district_clean  \
# 964                 12  20250401      Odisha   Nabarangapur
# ...

# %%
df_odisha_cleaned=df_odisha.drop(columns=['date','district','state'], axis=1)
df_odisha_cleaned
# Out:
#         pincode  age_0_5  age_5_17  age_18_greater  new_date state_clean  \
# 964      764076      182        82              12  20250401      Odisha
# 2175     751024       37        37              13  20250701      Odisha
# 2348     764074      327       103              12  20250701      Odisha
# 4926     759022        2         0               0  20250901      Odisha
# 4927     759100        1         1               0  20250901      Odisha
# ...         ...      ...       ...             ...       ...         ...
# 510653   754222        0         1               0  20251231      Odisha
# 510654   758078        1         0               0  20251231      Odisha
# 510655   751001        1         0               0  20251231      Odisha
# 510656   751006        1         0               0  20251231      Odisha
# 510657   765001        0         1               0  20251231      Odisha
#
#        district_clean  pin_multi_district_flag  total_enroll month
# ...

# %%
df_odisha_dist_level=df_odisha_cleaned.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater','total_enroll']].sum()
df_odisha_dist_level.shape
# Out:
# (30, 4)

# %%
df_odisha_dist_level
# Out:
#                 age_0_5  age_5_17  age_18_greater  total_enroll
# district_clean
# Angul              1567       286              10          1863
# Balangir           2641       638              23          3302
# Baleswar           3542       816               3          4361
# Bargarh            2491       520               2          3013
# Bhadrak            2275       768               1          3044
# Boudh               832       171               0          1003
# Cuttack            2403       655               7          3065
# Debagarh            391        59               2           452
# Dhenkanal          1367       343               0          1710
# Gajapati           1016       206               4          1226
# Ganjam             3634       593               2          4229
# Jagatsinghapur     2023       219               1          2243
# Jajpur             2095       612              12          2719
# ...

# %%
df_odisha_dist_level.sort_values('total_enroll', ascending=False).reset_index()
# Out:
#     district_clean  age_0_5  age_5_17  age_18_greater  total_enroll
# 0       Mayurbhanj     3970      1202               8          5180
# 1     Nabarangapur     3195      1449              27          4671
# 2         Baleswar     3542       816               3          4361
# 3           Ganjam     3634       593               2          4229
# 4         Balangir     2641       638              23          3302
# 5        Kendujhar     2418       652               5          3075
# 6          Cuttack     2403       655               7          3065
# 7          Koraput     2211       840               0          3051
# 8          Bhadrak     2275       768               1          3044
# 9          Bargarh     2491       520               2          3013
# 10         Khordha     2353       496              22          2871
# 11       Kalahandi     2155       687              26          2868
# 12      Sundargarh     2284       490              13          2787
# ...

# %%
df_odisha_dist_level1=df_odisha_dist_level.head(10)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_odisha_dist_level1[['age_0_5','age_5_17','age_18_greater']])
plt.show()

# %%
df_odisha_pincode_level=df_odisha_cleaned.groupby('pincode')[['age_0_5','age_5_17','age_18_greater','total_enroll']].sum()
df_odisha_pincode_level.shape
# Out:
# (905, 4)

# %%
df_odisha_pincode_level.sort_values('total_enroll', ascending=False).reset_index()
# Out:
#      pincode  age_0_5  age_5_17  age_18_greater  total_enroll
# 0     764074      548       189              13           750
# 1     764076      425       271              13           709
# 2     764071      368       201               0           569
# 3     764073      410       133               0           543
# 4     754141      458        46               1           505
# ..       ...      ...       ...             ...           ...
# 900   754288        1         0               0             1
# 901   763004        0         1               0             1
# 902   754145        1         0               0             1
# 903   769011        1         0               0             1
# 904   758052        0         1               0             1
#
# [905 rows x 5 columns]

# %%
df_odisha_pincode_level
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enroll
# pincode
# 751001        45         7               0            52
# 751002        94        16               0           110
# 751003        66        21               2            89
# 751004         1         1               0             2
# 751005         1         0               0             1
# ...          ...       ...             ...           ...
# 770072        19         0               0            19
# 770073        22         2               0            24
# 770074        39         7               0            46
# 770075        13         4               0            17
# 770076         7         2               0             9
#
# [905 rows x 4 columns]

# %%
df_odisha_pincode_level1=df_odisha_pincode_level.head(10)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_odisha_pincode_level1[['age_0_5','age_5_17','age_18_greater']])
plt.show()

# %%
odisha_month_enroll_trend=df_odisha_cleaned.groupby('month')[['age_0_5','age_5_17','age_18_greater','total_enroll']].sum()
odisha_month_enroll_trend
# Out:
#        age_0_5  age_5_17  age_18_greater  total_enroll
# month
# 04         182        82              12           276
# 07         364       140              25           529
# 09       42843     10426              51         53320
# 10       14094      3129              97         17320
# 12         888       728               6          1622

# %%
odisha_month_enroll_trend.to_excel("df_bihar_month_level.xlsx")

# %%
sns.lineplot(data=odisha_month_enroll_trend)
# Out:
# <Axes: xlabel='month'>
