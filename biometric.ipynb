# %% [markdown]
# # EDA Based on biomatric Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Biometric-1 File

# %%
a=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_biometric\\api_data_aadhar_biometric\\api_data_aadhar_biometric_0_500000.csv")
a.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
a.tail()
# Out:
#               date  state    district  pincode  bio_age_5_17  bio_age_17_
# 499995  19-09-2025  Delhi  West Delhi   110041           102          100
# 499996  19-09-2025  Delhi  West Delhi   110043             8            5
# 499997  19-09-2025  Delhi  West Delhi   110058             7            5
# 499998  19-09-2025    Goa   North Goa   403102             1            0
# 499999  19-09-2025    Goa   North Goa   403106             1            0

# %%
a.shape
# Out:
# (500000, 6)

# %%
a['state'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Andaman and Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'WESTBENGAL',
#        'andhra pradesh', 'Westbengal', 'West  Bengal', 'WEST BENGAL',
#        'West Bangal', 'ODISHA', 'odisha', 'West bengal', 'west Bengal',
# ...

# %%
a['new_date'] = pd.to_datetime(a['date'], dayfirst=True).dt.strftime('%Y %m %d')
a
# Out:
#               date              state      district  pincode  bio_age_5_17  \
# 0       01-03-2025            Haryana  Mahendragarh   123029           280
# 1       01-03-2025              Bihar     Madhepura   852121           144
# 2       01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3       01-03-2025              Bihar       Bhojpur   802158           256
# 4       01-03-2025         Tamil Nadu       Madurai   625514           271
# ...            ...                ...           ...      ...           ...
# 499995  19-09-2025              Delhi    West Delhi   110041           102
# 499996  19-09-2025              Delhi    West Delhi   110043             8
# 499997  19-09-2025              Delhi    West Delhi   110058             7
# 499998  19-09-2025                Goa     North Goa   403102             1
# 499999  19-09-2025                Goa     North Goa   403106             1
#
#         bio_age_17_    new_date
# 0               577  2025 03 01
# ...

# %%
a['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(a['new_date'].max())
print(a['new_date'].min())
# Out:
# 2025 09 19
# 2025 03 01

# %% [markdown]
# Biometric- 2

# %%
b=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_biometric\\api_data_aadhar_biometric\\api_data_aadhar_biometric_500000_1000000.csv")
b.head()
# Out:
#          date state   district  pincode  bio_age_5_17  bio_age_17_
# 0  19-09-2025   Goa  North Goa   403502             0            4
# 1  19-09-2025   Goa  North Goa   403508             1            4
# 2  19-09-2025   Goa  North Goa   403513             2            0
# 3  19-09-2025   Goa  North Goa   403527             2            2
# 4  19-09-2025   Goa  South Goa   403601             7            3

# %%
b.shape
# Out:
# (500000, 6)

# %%
b['state'].unique()
# Out:
# array(['Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Andhra Pradesh', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman & Diu', 'Delhi',
#        'Daman and Diu', 'West  Bengal',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Dadra & Nagar Haveli',
#        'West bengal', 'West Bangal', 'ODISHA', 'WEST BENGAL',
#        'andhra pradesh', 'odisha', 'Westbengal', 'WESTBENGAL'],
#       dtype=object)

# %%
b['new_date'] = pd.to_datetime(b['date'], dayfirst=True).dt.strftime('%Y %m %d')
b
# Out:
#               date   state   district  pincode  bio_age_5_17  bio_age_17_  \
# 0       19-09-2025     Goa  North Goa   403502             0            4
# 1       19-09-2025     Goa  North Goa   403508             1            4
# 2       19-09-2025     Goa  North Goa   403513             2            0
# 3       19-09-2025     Goa  North Goa   403527             2            2
# 4       19-09-2025     Goa  South Goa   403601             7            3
# ...            ...     ...        ...      ...           ...          ...
# 499995  07-11-2025  Kerala  Ernakulam   682020             1            6
# 499996  07-11-2025  Kerala  Ernakulam   682022             1            0
# 499997  07-11-2025  Kerala  Ernakulam   682023             0            1
# 499998  07-11-2025  Kerala  Ernakulam   682025             3            6
# 499999  07-11-2025  Kerala  Ernakulam   682026             1            3
#
#           new_date
# 0       2025 09 19
# 1       2025 09 19
# ...

# %%
b['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(b['new_date'].max())
print(b['new_date'].min())
# Out:
# 2025 11 07
# 2025 09 19

# %% [markdown]
# Biometric -3

# %%
c=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_biometric\\api_data_aadhar_biometric\\api_data_aadhar_biometric_1000000_1500000.csv")
c.head()
# Out:
#          date             state      district  pincode  bio_age_5_17  \
# 0  07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1  07-11-2025           Haryana   Yamunanagar   135001             1
# 2  07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3  07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4  07-11-2025  Himachal Pradesh      Bilaspur   174013             3
#
#    bio_age_17_
# 0            6
# 1            2
# 2            2
# 3            0
# 4            1

# %%
c.shape
# Out:
# (500000, 6)

# %%
c['state'].unique()
# Out:
# array(['Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Andaman & Nicobar Islands',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman & Diu',
#        'Daman and Diu', 'Delhi', 'Goa', 'Gujarat', 'Jammu & Kashmir',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Ladakh', 'West Bangal',
#        'West bengal', 'odisha',
#        'Dadra and Nagar Haveli and Daman and Diu', 'West  Bengal',
#        'WEST BENGAL', 'andhra pradesh', 'Westbengal', 'Chhatisgarh',
#        'ODISHA', 'WESTBENGAL', 'Uttaranchal'], dtype=object)

# %%
c['new_date'] = pd.to_datetime(c['date'], dayfirst=True).dt.strftime('%Y %m %d')
c
# Out:
#               date             state      district  pincode  bio_age_5_17  \
# 0       07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1       07-11-2025           Haryana   Yamunanagar   135001             1
# 2       07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3       07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4       07-11-2025  Himachal Pradesh      Bilaspur   174013             3
# ...            ...               ...           ...      ...           ...
# 499995  08-12-2025           Gujarat      Vadodara   391150             3
# 499996  08-12-2025           Gujarat      Vadodara   391168            11
# 499997  08-12-2025           Gujarat      Vadodara   391170             0
# 499998  08-12-2025           Gujarat      Vadodara   391410             9
# 499999  08-12-2025           Gujarat      Vadodara   391530             3
#
#         bio_age_17_    new_date
# 0                 6  2025 11 07
# ...

# %%
c['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(c['new_date'].max())
print(c['new_date'].min())
# Out:
# 2025 12 08
# 2025 11 07

# %%
d=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_biometric\\api_data_aadhar_biometric\\api_data_aadhar_biometric_1500000_1861108.csv")
d.head()
# Out:
#          date          state       district  pincode  bio_age_5_17  \
# 0  08-12-2025  Uttar Pradesh      Moradabad   244411             4
# 1  08-12-2025  Uttar Pradesh      Moradabad   244601            14
# 2  08-12-2025  Uttar Pradesh  Muzaffarnagar   251002            22
# 3  08-12-2025  Uttar Pradesh  Muzaffarnagar   251202             4
# 4  08-12-2025  Uttar Pradesh  Muzaffarnagar   251319             4
#
#    bio_age_17_
# 0            2
# 1           19
# 2           37
# 3            4
# 4            7

# %%
d.shape
# Out:
# (361108, 6)

# %%
d['state'].unique()
# Out:
# array(['Uttar Pradesh', 'Uttarakhand', 'West Bangal', 'West Bengal',
#        'West bengal', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir',
#        'Jharkhand', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Orissa', 'Pondicherry', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Andhra Pradesh', 'Arunachal Pradesh', 'Dadra & Nagar Haveli',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Tripura',
#        'Daman and Diu', 'Jammu & Kashmir', 'Daman & Diu', 'WEST BENGAL',
#        'ODISHA', 'Chhatisgarh', 'Westbengal', 'West  Bengal', 'Tamilnadu',
#        'andhra pradesh'], dtype=object)

# %%
d['new_date'] = pd.to_datetime(d['date'], dayfirst=True).dt.strftime('%Y %m %d')
d
# Out:
#               date          state        district  pincode  bio_age_5_17  \
# 0       08-12-2025  Uttar Pradesh       Moradabad   244411             4
# 1       08-12-2025  Uttar Pradesh       Moradabad   244601            14
# 2       08-12-2025  Uttar Pradesh   Muzaffarnagar   251002            22
# 3       08-12-2025  Uttar Pradesh   Muzaffarnagar   251202             4
# 4       08-12-2025  Uttar Pradesh   Muzaffarnagar   251319             4
# ...            ...            ...             ...      ...           ...
# 361103  29-12-2025    West Bengal  Uttar Dinajpur   733201             4
# 361104  29-12-2025    West Bengal  Uttar Dinajpur   733213             0
# 361105  29-12-2025    West Bengal  West Midnapore   721304             0
# 361106  29-12-2025    West Bengal  West Midnapore   721451             2
# 361107  29-12-2025    West Bengal  West Midnapore   721457             0
#
#         bio_age_17_    new_date
# 0                 2  2025 12 08
# ...

# %%
d['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(d['new_date'].max())
print(d['new_date'].min())
# Out:
# 2025 12 29
# 2025 12 08

# %%
#Merging 4 files

df = pd.concat([a, b, c, d], axis=0, ignore_index=True)
df.shape
# Out:
# (1861108, 7)

# %%
df.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_    new_date
# 0          577  2025 03 01
# 1          369  2025 03 01
# 2         1091  2025 03 01
# 3          980  2025 03 01
# 4          815  2025 03 01

# %%
df['state'].nunique()
# Out:
# 57

# %%
df['state'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Andaman and Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'WESTBENGAL',
#        'andhra pradesh', 'Westbengal', 'West  Bengal', 'WEST BENGAL',
#        'West Bangal', 'ODISHA', 'odisha', 'West bengal', 'west Bengal',
# ...

# %%
df['state'] = df['state'].replace('Tamilnadu', 'Tamil Nadu')

# %%
df['state'] = df['state'].replace('Uttaranchal', 'Uttarakhand')

# %%
import pandas as pd
import re

def clean_state_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove symbols like &, .
    x = re.sub(r'\s+', ' ', x).strip()  # remove extra spaces
    return x

# %%
state_mapping = {
    # West Bengal
    'west bengal': 'West Bengal',
    'west bangal': 'West Bengal',
    'westbengal': 'West Bengal',
    'west  bengal': 'West Bengal',
    'westbengal ': 'West Bengal',
    'west bengli':  'West Bengal',
    

    # Andhra Pradesh
    'andhra pradesh': 'Andhra Pradesh',

    # Odisha
    'odisha': 'Odisha',
    'orissa': 'Odisha',

    # Jammu & Kashmir
    'jammu and kashmir': 'Jammu and Kashmir',
    'jammu kashmir': 'Jammu and Kashmir',

    # Collapse all Dadra / Daman variants into ONE state
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'the dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman diu': 'Dadra and Nagar Haveli and Daman and Diu',


    # Puducherry
    'puducherry': 'Puducherry',


    # Andaman & Nicobar Islands
    'andaman and nicobar islands': 'Andaman and Nicobar Islands',
    'andaman nicobar islands': 'Andaman and Nicobar Islands',

    # Puducherry
    'pondicherry': 'Puducherry',

    # Case-normalized direct matches
    'delhi': 'Delhi',
    'ladakh': 'Ladakh',
    'goa': 'Goa',
    'sikkim': 'Sikkim',
    'assam': 'Assam',
    'bihar': 'Bihar',
    'punjab': 'Punjab',
    'kerala': 'Kerala',
    'haryana': 'Haryana',
    'gujarat': 'Gujarat',
    'tamil nadu': 'Tamil Nadu',
    'telangana': 'Telangana',
    'karnataka': 'Karnataka',
    'maharashtra': 'Maharashtra',
    'Nagpur': 'Maharashtra',
    'rajasthan': 'Rajasthan',
    'uttar pradesh': 'Uttar Pradesh',
    'madhya pradesh': 'Madhya Pradesh',
    'himachal pradesh': 'Himachal Pradesh',
    'arunachal pradesh': 'Arunachal Pradesh',
    'chhattisgarh': 'Chhattisgarh',
    'chhatisgarh' : 'Chhattisgarh',
    'jharkhand': 'Jharkhand',
    'manipur': 'Manipur',
    'meghalaya': 'Meghalaya',
    'mizoram': 'Mizoram',
    'nagaland': 'Nagaland',
    'tripura': 'Tripura',
    'uttarakhand': 'Uttarakhand',
    'lakshadweep': 'Lakshadweep',
    'chandigarh': 'Chandigarh'
}

# %%
df['state_clean'] = (
    df['state']
    .apply(clean_state_name)
    .map(state_mapping)
)

# %%
# Drop invalid entries like numeric junk
df = df[~df['state'].astype(str).str.isnumeric()]

# Optional: check unmapped states
unmapped = df[df['state_clean'].isna()]['state'].unique()
print("Unmapped values:", unmapped)
# Out:
# Unmapped values: []

# %%
df.tail(20)
# Out:
#                date        state                    district  pincode  \
# 1861088  29-12-2025  West Bengal           South 24 Parganas   743375
# 1861089  29-12-2025  West Bengal           South 24 Parganas   743378
# 1861090  29-12-2025  West Bengal           South 24 Parganas   743384
# 1861091  29-12-2025  West Bengal           South 24 Parganas   743392
# 1861092  29-12-2025  West Bengal           South 24 Parganas   743502
# 1861093  29-12-2025  West Bengal              South Dinajpur   733126
# 1861094  29-12-2025  West Bengal              South Dinajpur   733140
# 1861095  29-12-2025  West Bengal              South Dinajpur   733145
# 1861096  29-12-2025  West Bengal              South Dinajpur   733153
# 1861097  29-12-2025  West Bengal              South Dinajpur   733155
# 1861098  29-12-2025  West Bengal  South Twenty Four Parganas   700084
# 1861099  29-12-2025  West Bengal  South Twenty Four Parganas   700145
# ...

# %%
df['state_clean'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Puducherry',
#        'Manipur', 'Sikkim', 'Tripura', 'Mizoram', 'Arunachal Pradesh',
#        'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Andaman and Nicobar Islands', 'Lakshadweep'], dtype=object)

# %%
df['state_clean'].nunique()
# Out:
# 36

# %%
df.dtypes
# Out:
# date            object
# state           object
# district        object
# pincode          int64
# bio_age_5_17     int64
# bio_age_17_      int64
# new_date        object
# state_clean     object
# dtype: object

# %%
df_odisha=df[df['state_clean']=='Odisha']
df_odisha
# Out:
#                date   state      district  pincode  bio_age_5_17  bio_age_17_  \
# 8        01-03-2025  Odisha     Dhenkanal   759025           122          214
# 28       01-03-2025  Odisha  Nabarangapur   764075           438          605
# 38       01-03-2025  Odisha    Sundergarh   769004           152          186
# 48       01-03-2025  Odisha       Cuttack   753003            40          112
# 104      01-03-2025  Odisha      Balangir   767033           247          482
# ...             ...     ...           ...      ...           ...          ...
# 1859275  29-12-2025  Orissa      Nayagarh   752068             1            0
# 1859276  29-12-2025  Orissa      Nayagarh   752070             1            1
# 1859277  29-12-2025  Orissa      Nayagarh   752077             0            1
# 1859278  29-12-2025  Orissa          Puri   752121             0            1
# 1859279  29-12-2025  Orissa     Sambalpur   768002             0            1
#
#            new_date state_clean
# ...

# %%
df_odisha['district'].unique()
# Out:
# array(['Dhenkanal', 'Nabarangapur', 'Sundergarh', 'Cuttack', 'Balangir',
#        'Kendrapara', 'Khorda', 'Baleswar', 'Jajapur', 'Mayurbhanj',
#        'Kalahandi', 'Koraput', 'Ganjam', 'Puri', 'JAJPUR', 'Sonapur',
#        'Boudh', 'Kandhamal', 'Angul', 'Nayagarh', 'Sundargarh', 'Baudh',
#        'Bhadrak', 'Baleshwar', 'Bargarh', 'Sambalpur', 'Kendujhar',
#        'Rayagada', 'Gajapati', 'Anugul', 'Khordha', 'Jagatsinghapur',
#        'Jagatsinghpur', 'Subarnapur', 'Jharsuguda', 'Malkangiri',
#        'Nuapada', 'Debagarh', 'ANUGUL', 'Jajpur', 'jajpur', 'NUAPADA',
#        'BALANGIR', 'NAYAGARH', 'Anugal', 'Khordha  *'], dtype=object)

# %%
import re
import pandas as pd

def clean_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove (), ., etc
    x = re.sub(r'\s+', ' ', x).strip()
    return x

# %%
district_mapping_odisha = {

    # Angul
    'angul': 'Angul',
    'anugul': 'Angul',
    'anugal': 'Angul',
    'anugul ': 'Angul',
    'anugul*': 'Angul',
    'anugul  *': 'Angul',

    # Balangir
    'balangir': 'Balangir',
    'bolangir': 'Balangir',

    # Baleswar (Balasore)
    'baleswar': 'Baleswar',
    'baleshwar': 'Baleswar',
    'balasore': 'Baleswar',

    # Bargarh
    'bargarh': 'Bargarh',

    # Bhadrak
    'bhadrak': 'Bhadrak',

    # Boudh
    'boudh': 'Boudh',
    'baudh': 'Boudh',

    # Cuttack
    'cuttack': 'Cuttack',

    # Debagarh
    'debagarh': 'Debagarh',
    'deogarh': 'Debagarh',

    # Dhenkanal
    'dhenkanal': 'Dhenkanal',

    # Gajapati
    'gajapati': 'Gajapati',

    # Ganjam
    'ganjam': 'Ganjam',

    # Jagatsinghapur
    'jagatsinghapur': 'Jagatsinghapur',
    'jagatsinghpur': 'Jagatsinghapur',

    # Jajpur
    'jajapur': 'Jajpur',
    'jajpur': 'Jajpur',
    'jajpur ': 'Jajpur',

    # Jharsuguda
    'jharsuguda': 'Jharsuguda',

    # Kalahandi
    'kalahandi': 'Kalahandi',

    # Kandhamal
    'kandhamal': 'Kandhamal',
    'phulbani': 'Kandhamal',

    # Kendrapara
    'kendrapara': 'Kendrapara',

    # Kendujhar (Keonjhar)
    'kendujhar': 'Kendujhar',
    'keonjhar': 'Kendujhar',

    # Khordha
    'khorda': 'Khordha',
    'khordha': 'Khordha',
    'khordha  *': 'Khordha',

    # Koraput
    'koraput': 'Koraput',

    # Malkangiri
    'malkangiri': 'Malkangiri',

    # Mayurbhanj
    'mayurbhanj': 'Mayurbhanj',

    # Nabarangapur
    'nabarangapur': 'Nabarangapur',
    'nabarangpur': 'Nabarangapur',

    # Nayagarh
    'nayagarh': 'Nayagarh',

    # Nuapada
    'nuapada': 'Nuapada',

    # Puri
    'puri': 'Puri',

    # Rayagada
    'rayagada': 'Rayagada',

    # Sambalpur
    'sambalpur': 'Sambalpur',

    # Subarnapur (Sonapur)
    'sonapur': 'Subarnapur',
    'subarnapur': 'Subarnapur',

    # Sundargarh
    'sundergarh': 'Sundargarh',
    'sundargarh': 'Sundargarh',
}

# %%
df_odisha = df_odisha.copy()

# %%
df_odisha.loc[:, 'district_clean'] = (
    df_odisha['district']
    .apply(clean_name)
    .map(district_mapping_odisha)
    .fillna(df_odisha['district'])
)

# %%
df_odisha
# Out:
#                date   state      district  pincode  bio_age_5_17  bio_age_17_  \
# 8        01-03-2025  Odisha     Dhenkanal   759025           122          214
# 28       01-03-2025  Odisha  Nabarangapur   764075           438          605
# 38       01-03-2025  Odisha    Sundergarh   769004           152          186
# 48       01-03-2025  Odisha       Cuttack   753003            40          112
# 104      01-03-2025  Odisha      Balangir   767033           247          482
# ...             ...     ...           ...      ...           ...          ...
# 1859275  29-12-2025  Orissa      Nayagarh   752068             1            0
# 1859276  29-12-2025  Orissa      Nayagarh   752070             1            1
# 1859277  29-12-2025  Orissa      Nayagarh   752077             0            1
# 1859278  29-12-2025  Orissa          Puri   752121             0            1
# 1859279  29-12-2025  Orissa     Sambalpur   768002             0            1
#
# ...

# %%
pin_district_count = (
    df_odisha.groupby('pincode')['district_clean']
      .nunique()
      .reset_index(name='district_count')
)

# %%
pin_district_count
# Out:
#      pincode  district_count
# 0     751001               1
# 1     751002               2
# 2     751003               1
# 3     751004               1
# 4     751005               1
# ..       ...             ...
# 935   770072               1
# 936   770073               1
# 937   770074               1
# 938   770075               1
# 939   770076               1
#
# [940 rows x 2 columns]

# %%
problem_pins = pin_district_count[
    pin_district_count['district_count'] > 1
]

# %%
problem_pins
# Out:
#      pincode  district_count
# 1     751002               2
# 29    752001               2
# 36    752015               3
# 40    752019               2
# 41    752020               2
# ..       ...             ...
# 869   768217               2
# 873   768221               3
# 874   768222               2
# 875   768224               2
# 879   768228               3
#
# [161 rows x 2 columns]

# %%
df_flagged = df_odisha.merge(
    problem_pins[['pincode']],
    on='pincode',
    how='inner'
)

# %%
df_flagged
# Out:
#              date   state      district  pincode  bio_age_5_17  bio_age_17_  \
# 0      01-03-2025  Odisha  Nabarangapur   764075           438          605
# 1      01-03-2025  Odisha        Khorda   754001            23           31
# 2      01-03-2025  Orissa          Puri   752106            11           83
# 3      01-03-2025  Odisha        JAJPUR   755001            28           35
# 4      01-03-2025  Odisha       Sonapur   767020            10           40
# ...           ...     ...           ...      ...           ...          ...
# 23256  29-12-2025  Orissa       Khordha   752064             0            1
# 23257  29-12-2025  Orissa       Khordha   752100             0            1
# 23258  29-12-2025  Orissa      Nayagarh   752068             1            0
# 23259  29-12-2025  Orissa      Nayagarh   752070             1            1
# 23260  29-12-2025  Orissa      Nayagarh   752077             0            1
#
#          new_date state_clean district_clean
# ...

# %%
df_odisha_cleaned=df_odisha.drop(columns=['date','district','state'], axis=1)
df_odisha_cleaned
# Out:
#          pincode  bio_age_5_17  bio_age_17_    new_date state_clean  \
# 8         759025           122          214  2025 03 01      Odisha
# 28        764075           438          605  2025 03 01      Odisha
# 38        769004           152          186  2025 03 01      Odisha
# 48        753003            40          112  2025 03 01      Odisha
# 104       767033           247          482  2025 03 01      Odisha
# ...          ...           ...          ...         ...         ...
# 1859275   752068             1            0  2025 12 29      Odisha
# 1859276   752070             1            1  2025 12 29      Odisha
# 1859277   752077             0            1  2025 12 29      Odisha
# 1859278   752121             0            1  2025 12 29      Odisha
# 1859279   768002             0            1  2025 12 29      Odisha
#
#         district_clean
# 8            Dhenkanal
# 28        Nabarangapur
# 38          Sundargarh
# 48             Cuttack
# 104           Balangir
# ...

# %%
df_odisha['total_enroll']=df_odisha['bio_age_5_17']+df_odisha['bio_age_17_']
df_odisha
# Out:
#                date   state      district  pincode  bio_age_5_17  bio_age_17_  \
# 8        01-03-2025  Odisha     Dhenkanal   759025           122          214
# 28       01-03-2025  Odisha  Nabarangapur   764075           438          605
# 38       01-03-2025  Odisha    Sundergarh   769004           152          186
# 48       01-03-2025  Odisha       Cuttack   753003            40          112
# 104      01-03-2025  Odisha      Balangir   767033           247          482
# ...             ...     ...           ...      ...           ...          ...
# 1859275  29-12-2025  Orissa      Nayagarh   752068             1            0
# 1859276  29-12-2025  Orissa      Nayagarh   752070             1            1
# 1859277  29-12-2025  Orissa      Nayagarh   752077             0            1
# 1859278  29-12-2025  Orissa          Puri   752121             0            1
# 1859279  29-12-2025  Orissa     Sambalpur   768002             0            1
#
# ...

# %%
df_odisha['month']=df_odisha['new_date'].astype(str).str[4:6]
df_odisha
# Out:
#                date   state      district  pincode  bio_age_5_17  bio_age_17_  \
# 8        01-03-2025  Odisha     Dhenkanal   759025           122          214
# 28       01-03-2025  Odisha  Nabarangapur   764075           438          605
# 38       01-03-2025  Odisha    Sundergarh   769004           152          186
# 48       01-03-2025  Odisha       Cuttack   753003            40          112
# 104      01-03-2025  Odisha      Balangir   767033           247          482
# ...             ...     ...           ...      ...           ...          ...
# 1859275  29-12-2025  Orissa      Nayagarh   752068             1            0
# 1859276  29-12-2025  Orissa      Nayagarh   752070             1            1
# 1859277  29-12-2025  Orissa      Nayagarh   752077             0            1
# 1859278  29-12-2025  Orissa          Puri   752121             0            1
# 1859279  29-12-2025  Orissa     Sambalpur   768002             0            1
#
# ...

# %%
df_odisha_cleaned=df_odisha.drop(columns=['date','district','state'], axis=1)
df_odisha_cleaned
# Out:
#          pincode  bio_age_5_17  bio_age_17_    new_date state_clean  \
# 8         759025           122          214  2025 03 01      Odisha
# 28        764075           438          605  2025 03 01      Odisha
# 38        769004           152          186  2025 03 01      Odisha
# 48        753003            40          112  2025 03 01      Odisha
# 104       767033           247          482  2025 03 01      Odisha
# ...          ...           ...          ...         ...         ...
# 1859275   752068             1            0  2025 12 29      Odisha
# 1859276   752070             1            1  2025 12 29      Odisha
# 1859277   752077             0            1  2025 12 29      Odisha
# 1859278   752121             0            1  2025 12 29      Odisha
# 1859279   768002             0            1  2025 12 29      Odisha
#
#         district_clean  total_enroll month
# 8            Dhenkanal           336     0
# 28        Nabarangapur          1043     0
# ...

# %%
df_odisha_dist_level=df_odisha_cleaned.groupby('district_clean')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
df_odisha_dist_level.shape
# Out:
# (30, 3)

# %%
df_odisha_dist_level
# Out:
#                 bio_age_5_17  bio_age_17_  total_enroll
# district_clean
# Angul                  31151        33120         64271
# Balangir               47948        50646         98594
# Baleswar               63670        61081        124751
# Bargarh                39915        38936         78851
# Bhadrak                51710        43851         95561
# Boudh                  12339        15229         27568
# Cuttack                65920        73747        139667
# Debagarh                8000         7601         15601
# Dhenkanal              36743        39288         76031
# Gajapati               27557        28148         55705
# Ganjam                 99284        92517        191801
# Jagatsinghapur         29631        30646         60277
# Jajpur                 48913        47703         96616
# Jharsuguda             13378        12454         25832
# Kalahandi              41612        50889         92501
# ...

# %%
df_odisha_dist_level=df_odisha_dist_level.sort_values('total_enroll', ascending=False).reset_index()

# %%
df_odisha_dist_level1=df_odisha_dist_level.head(10)
df_odisha_dist_level1
# Out:
#   district_clean  bio_age_5_17  bio_age_17_  total_enroll
# 0         Ganjam         99284        92517        191801
# 1     Mayurbhanj         76864        78386        155250
# 2        Cuttack         65920        73747        139667
# 3       Baleswar         63670        61081        124751
# 4        Khordha         53701        64179        117880
# 5     Sundargarh         49844        59002        108846
# 6        Koraput         46654        56299        102953
# 7      Kendujhar         45491        54076         99567
# 8       Balangir         47948        50646         98594
# 9         Jajpur         48913        47703         96616

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_odisha_dist_level1[['bio_age_5_17','bio_age_17_']])
plt.show()

# %%
df_odisha_pincode_level=df_odisha_cleaned.groupby('pincode')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
df_odisha_pincode_level.shape
# Out:
# (940, 3)

# %%
df_odisha_pincode_level.sort_values('total_enroll', ascending=False).reset_index()
# Out:
#      pincode  bio_age_5_17  bio_age_17_  total_enroll
# 0     764043          7851         9428         17279
# 1     764072          6504         6505         13009
# 2     764073          6749         6106         12855
# 3     764074          6596         5431         12027
# 4     766105          5006         5789         10795
# ..       ...           ...          ...           ...
# 935   752112             1            1             2
# 936   755045             0            1             1
# 937   758084             1            0             1
# 938   758087             1            0             1
# 939   758085             0            1             1
#
# [940 rows x 4 columns]

# %%
df_odisha_pincode_level=df_odisha_pincode_level.sort_values('total_enroll', ascending=False).reset_index()

# %%
df_odisha_pincode_level1=df_odisha_pincode_level.head(10)
df_odisha_pincode_level1
# Out:
#    pincode  bio_age_5_17  bio_age_17_  total_enroll
# 0   764043          7851         9428         17279
# 1   764072          6504         6505         13009
# 2   764073          6749         6106         12855
# 3   764074          6596         5431         12027
# 4   766105          5006         5789         10795
# 5   764076          5644         4678         10322
# 6   764044          4615         5130          9745
# 7   766002          4389         5115          9504
# 8   754141          4899         4502          9401
# 9   764002          3544         5693          9237

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_odisha_pincode_level1[['bio_age_5_17','bio_age_17_','total_enroll']])
plt.show()

# %%
odisha_month_enroll_trend=df_odisha_cleaned.groupby('month')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
odisha_month_enroll_trend
# Out:
#        bio_age_5_17  bio_age_17_  total_enroll
# month
#              155088        99181        254269
#  0           791744       967001       1758745
#  1           243542       167722        411264

# %%
sns.lineplot(data=odisha_month_enroll_trend)
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# # iometric
