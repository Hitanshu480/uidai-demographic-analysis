# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Demography-1 file

# %%
a=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_demographic\\api_data_aadhar_demographic\\api_data_aadhar_demographic_0_500000.csv")
a.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
a.shape
# Out:
# (500000, 6)

# %%
a['new_date'] = pd.to_datetime(a['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
a
# Out:
#               date           state    district  pincode  demo_age_5_17  \
# 0       01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1       01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2       01-03-2025         Gujarat      Rajkot   360006             65
# 3       01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4       01-03-2025       Rajasthan     Udaipur   313801             45
# ...            ...             ...         ...      ...            ...
# 499995  19-09-2025     Maharashtra      Satara   415212              0
# 499996  19-09-2025     Maharashtra      Satara   415312              0
# 499997  19-09-2025     Maharashtra      Satara   415510              0
# 499998  19-09-2025     Maharashtra      Satara   415511              0
# 499999  19-09-2025     Maharashtra      Satara   415516              0
#
#         demo_age_17_  new_date
# 0                529  20250301
# 1                375  20250301
# ...

# %%
a['state'].unique()
# Out:
# array(['Uttar Pradesh', 'Andhra Pradesh', 'Gujarat', 'Rajasthan',
#        'Karnataka', 'West Bengal', 'Telangana', 'Odisha', 'Maharashtra',
#        'Kerala', 'Bihar', 'Tamil Nadu', 'Madhya Pradesh', 'Assam',
#        'Tripura', 'Arunachal Pradesh', 'Punjab', 'Jharkhand', 'Delhi',
#        'Chandigarh', 'Chhattisgarh', 'Jammu and Kashmir', 'Mizoram',
#        'Nagaland', 'Himachal Pradesh', 'Goa', 'Haryana', 'Meghalaya',
#        'Uttarakhand', 'Manipur', 'Daman and Diu', 'Puducherry', 'Sikkim',
#        'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Dadra and Nagar Haveli', 'Orissa', 'Pondicherry',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'west Bengal', 'Daman & Diu', 'West  Bengal', 'odisha',
#        'Jammu & Kashmir', 'Lakshadweep', 'Dadra & Nagar Haveli',
#        'Westbengal', 'andhra pradesh', 'WEST BENGAL', 'West Bangal',
#        'West bengal', 'ODISHA', 'WESTBENGAL', 'Chhatisgarh',
# ...

# %%
a['new_date'] = pd.to_datetime(a['date'], dayfirst=True).dt.strftime('%Y %m %d')
a
# Out:
#               date           state    district  pincode  demo_age_5_17  \
# 0       01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1       01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2       01-03-2025         Gujarat      Rajkot   360006             65
# 3       01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4       01-03-2025       Rajasthan     Udaipur   313801             45
# ...            ...             ...         ...      ...            ...
# 499995  19-09-2025     Maharashtra      Satara   415212              0
# 499996  19-09-2025     Maharashtra      Satara   415312              0
# 499997  19-09-2025     Maharashtra      Satara   415510              0
# 499998  19-09-2025     Maharashtra      Satara   415511              0
# 499999  19-09-2025     Maharashtra      Satara   415516              0
#
#         demo_age_17_    new_date
# 0                529  2025 03 01
# 1                375  2025 03 01
# ...

# %%
a['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(a['new_date'].max())
print(a['new_date'].min())
# Out:
# 2025 12 29
# 2025 03 01

# %% [markdown]
# Demography-2 file

# %%
b=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_demographic\\api_data_aadhar_demographic\\api_data_aadhar_demographic_500000_1000000.csv")
b.head()
# Out:
#          date        state    district  pincode  demo_age_5_17  demo_age_17_
# 0  19-09-2025  Maharashtra      Satara   415517              0             2
# 1  19-09-2025  Maharashtra      Satara   415518              0             2
# 2  19-09-2025  Maharashtra      Satara   415520              0             3
# 3  19-09-2025  Maharashtra      Satara   415539              1             5
# 4  19-09-2025  Maharashtra  Sindhudurg   416510              4            37

# %%
b.shape
# Out:
# (500000, 6)

# %%
b['new_date'] = pd.to_datetime(b['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
b
# Out:
#               date          state    district  pincode  demo_age_5_17  \
# 0       19-09-2025    Maharashtra      Satara   415517              0
# 1       19-09-2025    Maharashtra      Satara   415518              0
# 2       19-09-2025    Maharashtra      Satara   415520              0
# 3       19-09-2025    Maharashtra      Satara   415539              1
# 4       19-09-2025    Maharashtra  Sindhudurg   416510              4
# ...            ...            ...         ...      ...            ...
# 499995  31-10-2025  Uttar Pradesh        Etah   207250              2
# 499996  31-10-2025  Uttar Pradesh        Etah   207401              1
# 499997  31-10-2025  Uttar Pradesh      Etawah   206003              3
# 499998  31-10-2025  Uttar Pradesh      Etawah   206125              1
# 499999  31-10-2025  Uttar Pradesh      Etawah   206126              1
#
#         demo_age_17_  new_date
# 0                  2  20250919
# 1                  2  20250919
# ...

# %%
b['state'].unique()
# Out:
# array(['Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'ODISHA', 'Odisha', 'Orissa', 'Pondicherry', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Sikkim', 'Uttarakhand', 'West  Bengal',
#        'West Bengal', 'Andaman & Nicobar Islands', 'odisha',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Lakshadweep', 'Madhya Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'west Bengal', 'Daman & Diu', 'Dadra & Nagar Haveli',
#        'West Bangal', 'Westbengal', 'andhra pradesh', 'WESTBENGAL',
#        'WEST BENGAL', 'West bengal', 'West Bengli', 'BALANAGAR',
# ...

# %%
b['new_date'] = pd.to_datetime(b['date'], dayfirst=True).dt.strftime('%Y %m %d')
b
# Out:
#               date          state    district  pincode  demo_age_5_17  \
# 0       19-09-2025    Maharashtra      Satara   415517              0
# 1       19-09-2025    Maharashtra      Satara   415518              0
# 2       19-09-2025    Maharashtra      Satara   415520              0
# 3       19-09-2025    Maharashtra      Satara   415539              1
# 4       19-09-2025    Maharashtra  Sindhudurg   416510              4
# ...            ...            ...         ...      ...            ...
# 499995  31-10-2025  Uttar Pradesh        Etah   207250              2
# 499996  31-10-2025  Uttar Pradesh        Etah   207401              1
# 499997  31-10-2025  Uttar Pradesh      Etawah   206003              3
# 499998  31-10-2025  Uttar Pradesh      Etawah   206125              1
# 499999  31-10-2025  Uttar Pradesh      Etawah   206126              1
#
#         demo_age_17_    new_date
# 0                  2  2025 09 19
# 1                  2  2025 09 19
# ...

# %%
b['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(b['new_date'].max())
print(b['new_date'].min())
# Out:
# 2025 12 29
# 2025 03 01

# %% [markdown]
# Demography-3 file

# %%
c=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_demographic\\api_data_aadhar_demographic\\api_data_aadhar_demographic_1000000_1500000.csv")
c.head()
# Out:
#          date       state    district  pincode  demo_age_5_17  demo_age_17_
# 0  01-11-2025  Puducherry    Karaikal   609603              0             4
# 1  01-11-2025  Puducherry    Karaikal   609605              0             3
# 2  01-11-2025  Puducherry    Karaikal   609606              0             5
# 3  01-11-2025  Puducherry  Puducherry   605011              2             6
# 4  01-11-2025  Puducherry  Puducherry   605111              0             1

# %%
c['new_date'] = pd.to_datetime(c['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
c
# Out:
#               date       state    district  pincode  demo_age_5_17  \
# 0       01-11-2025  Puducherry    Karaikal   609603              0
# 1       01-11-2025  Puducherry    Karaikal   609605              0
# 2       01-11-2025  Puducherry    Karaikal   609606              0
# 3       01-11-2025  Puducherry  Puducherry   605011              2
# 4       01-11-2025  Puducherry  Puducherry   605111              0
# ...            ...         ...         ...      ...            ...
# 499995  19-11-2025   Rajasthan       Baran   325217              5
# 499996  19-11-2025   Rajasthan       Baran   325219              2
# 499997  19-11-2025   Rajasthan       Baran   325221             12
# 499998  19-11-2025   Rajasthan      Barmer   344011              1
# 499999  19-11-2025   Rajasthan      Barmer   344022              6
#
#         demo_age_17_  new_date
# 0                  4  20251101
# 1                  3  20251101
# 2                  5  20251101
# 3                  6  20251101
# ...

# %%
c['state'].unique()
# Out:
# array(['Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh',
#        'Chhattisgarh', 'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh',
#        'andhra pradesh', 'Daman & Diu', 'Lakshadweep', 'West Bangal',
#        'Jammu & Kashmir', 'Andaman & Nicobar Islands', 'ODISHA',
#        'WESTBENGAL', 'West  Bengal', 'West bengal', 'Westbengal',
#        'odisha', 'WEST BENGAL', 'Uttaranchal', 'west Bengal',
# ...

# %%
c['new_date'] = pd.to_datetime(c['date'], dayfirst=True).dt.strftime('%Y %m %d')
c
# Out:
#               date       state    district  pincode  demo_age_5_17  \
# 0       01-11-2025  Puducherry    Karaikal   609603              0
# 1       01-11-2025  Puducherry    Karaikal   609605              0
# 2       01-11-2025  Puducherry    Karaikal   609606              0
# 3       01-11-2025  Puducherry  Puducherry   605011              2
# 4       01-11-2025  Puducherry  Puducherry   605111              0
# ...            ...         ...         ...      ...            ...
# 499995  19-11-2025   Rajasthan       Baran   325217              5
# 499996  19-11-2025   Rajasthan       Baran   325219              2
# 499997  19-11-2025   Rajasthan       Baran   325221             12
# 499998  19-11-2025   Rajasthan      Barmer   344011              1
# 499999  19-11-2025   Rajasthan      Barmer   344022              6
#
#         demo_age_17_    new_date
# 0                  4  2025 11 01
# 1                  3  2025 11 01
# 2                  5  2025 11 01
# ...

# %%
c['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(c['new_date'].max())
print(c['new_date'].min())
# Out:
# 2025 12 29
# 2025 03 01

# %% [markdown]
# Demography-4 file

# %%
d=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_demographic\\api_data_aadhar_demographic\\api_data_aadhar_demographic_1500000_2000000.csv")
d.head()
# Out:
#          date      state district  pincode  demo_age_5_17  demo_age_17_
# 0  18-11-2025  Karnataka    Hasan   573118              0             2
# 1  18-11-2025  Karnataka    Hasan   573124              1             3
# 2  18-11-2025  Karnataka    Hasan   573150              0             2
# 3  18-11-2025  Karnataka   Hassan   573113              0             1
# 4  18-11-2025  Karnataka   Hassan   573120              1             4

# %%
d['new_date'] = pd.to_datetime(d['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
d
# Out:
#               date        state   district  pincode  demo_age_5_17  \
# 0       18-11-2025    Karnataka      Hasan   573118              0
# 1       18-11-2025    Karnataka      Hasan   573124              1
# 2       18-11-2025    Karnataka      Hasan   573150              0
# 3       18-11-2025    Karnataka     Hassan   573113              0
# 4       18-11-2025    Karnataka     Hassan   573120              1
# ...            ...          ...        ...      ...            ...
# 499995  16-12-2025  Maharashtra  Dharashiv   413506              1
# 499996  16-12-2025  Maharashtra  Dharashiv   413507              0
# 499997  16-12-2025  Maharashtra  Dharashiv   413601              0
# 499998  16-12-2025  Maharashtra  Dharashiv   413602              0
# 499999  16-12-2025  Maharashtra      Dhule   424301              0
#
#         demo_age_17_  new_date
# 0                  2  20251118
# 1                  3  20251118
# 2                  2  20251118
# 3                  1  20251118
# ...

# %%
d['state'].unique()
# Out:
# array(['Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh', 'Maharashtra',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Jammu and Kashmir', 'Jharkhand',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh', 'Assam', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman & Diu',
#        'Daman and Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'ODISHA',
#        'Arunachal Pradesh', 'Tripura', 'Andaman & Nicobar Islands',
#        'Lakshadweep', 'West Bengli', 'West  Bengal', 'West Bangal',
#        'Westbengal', 'Dadra & Nagar Haveli', 'West bengal', 'BALANAGAR',
#        'Uttaranchal', 'WESTBENGAL', 'WEST BENGAL', 'Jaipur',
# ...

# %%
d['new_date'] = pd.to_datetime(d['date'], dayfirst=True).dt.strftime('%Y %m %d')
d
# Out:
#               date        state   district  pincode  demo_age_5_17  \
# 0       18-11-2025    Karnataka      Hasan   573118              0
# 1       18-11-2025    Karnataka      Hasan   573124              1
# 2       18-11-2025    Karnataka      Hasan   573150              0
# 3       18-11-2025    Karnataka     Hassan   573113              0
# 4       18-11-2025    Karnataka     Hassan   573120              1
# ...            ...          ...        ...      ...            ...
# 499995  16-12-2025  Maharashtra  Dharashiv   413506              1
# 499996  16-12-2025  Maharashtra  Dharashiv   413507              0
# 499997  16-12-2025  Maharashtra  Dharashiv   413601              0
# 499998  16-12-2025  Maharashtra  Dharashiv   413602              0
# 499999  16-12-2025  Maharashtra      Dhule   424301              0
#
#         demo_age_17_    new_date
# 0                  2  2025 11 18
# 1                  3  2025 11 18
# 2                  2  2025 11 18
# ...

# %%
d['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(d['new_date'].max())
print(d['new_date'].min())
# Out:
# 2025 12 29
# 2025 03 01

# %% [markdown]
# Demography-5 file

# %%
e=pd.read_csv("C:\\Users\\hitan\\Downloads\\api_data_aadhar_demographic\\api_data_aadhar_demographic\\api_data_aadhar_demographic_2000000_2071700.csv")
e.head()
# Out:
#          date           state  district  pincode  demo_age_5_17  demo_age_17_
# 0  16-12-2025  Madhya Pradesh  Shajapur   465113              0             4
# 1  16-12-2025  Madhya Pradesh  Shajapur   465226              2            14
# 2  16-12-2025  Madhya Pradesh  Shajapur   465339              1             2
# 3  16-12-2025  Madhya Pradesh  Shajapur   465447              1            19
# 4  16-12-2025  Madhya Pradesh   Sheopur   476332             11            25

# %%
e['new_date'] = pd.to_datetime(e['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
e
# Out:
#              date           state        district  pincode  demo_age_5_17  \
# 0      16-12-2025  Madhya Pradesh        Shajapur   465113              0
# 1      16-12-2025  Madhya Pradesh        Shajapur   465226              2
# 2      16-12-2025  Madhya Pradesh        Shajapur   465339              1
# 3      16-12-2025  Madhya Pradesh        Shajapur   465447              1
# 4      16-12-2025  Madhya Pradesh         Sheopur   476332             11
# ...           ...             ...             ...      ...            ...
# 71695  29-12-2025     West Bengal  West Midnapore   721212              0
# 71696  29-12-2025     West Bengal  West Midnapore   721420              0
# 71697  29-12-2025     West Bengal  West Midnapore   721424              0
# 71698  29-12-2025     West Bengal  West Midnapore   721426              0
# 71699  29-12-2025     West Bengal         hooghly   712701              0
#
#        demo_age_17_  new_date
# 0                 4  20251216
# ...

# %%
e['state'].unique()
# Out:
# array(['Madhya Pradesh', 'Maharashtra', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bangal', 'West Bengal', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Orissa', 'Pondicherry', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'West bengal', 'andhra pradesh', 'west Bengal',
#        'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Daman & Diu',
#        'Daman and Diu', 'Ladakh', 'Lakshadweep', 'Sikkim', 'Westbengal',
#        '100000', 'Andaman & Nicobar Islands',
#        'Andaman and Nicobar Islands', 'Dadra & Nagar Haveli', 'ODISHA',
#        'odisha', 'Nagpur', 'WESTBENGAL', 'WEST BENGAL',
# ...

# %%
e['new_date'] = pd.to_datetime(e['date'], dayfirst=True).dt.strftime('%Y %m %d')
e
# Out:
#              date           state        district  pincode  demo_age_5_17  \
# 0      16-12-2025  Madhya Pradesh        Shajapur   465113              0
# 1      16-12-2025  Madhya Pradesh        Shajapur   465226              2
# 2      16-12-2025  Madhya Pradesh        Shajapur   465339              1
# 3      16-12-2025  Madhya Pradesh        Shajapur   465447              1
# 4      16-12-2025  Madhya Pradesh         Sheopur   476332             11
# ...           ...             ...             ...      ...            ...
# 71695  29-12-2025     West Bengal  West Midnapore   721212              0
# 71696  29-12-2025     West Bengal  West Midnapore   721420              0
# 71697  29-12-2025     West Bengal  West Midnapore   721424              0
# 71698  29-12-2025     West Bengal  West Midnapore   721426              0
# 71699  29-12-2025     West Bengal         hooghly   712701              0
#
#        demo_age_17_    new_date
# 0                 4  2025 12 16
# ...

# %%
e['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(e['new_date'].max())
print(e['new_date'].min())
# Out:
# 2025 12 29
# 2025 11 25

# %%
df = pd.concat([a, b,c ,d ,e], axis=0, ignore_index=True)
df.shape
# Out:
# (2071700, 7)

# %%
df.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_    new_date
# 0           529  2025 03 01
# 1           375  2025 03 01
# 2           765  2025 03 01
# 3           314  2025 03 01
# 4           785  2025 03 01

# %%
df['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['state'].nunique()
# Out:
# 65

# %%
df['state'].unique()
# Out:
# array(['Uttar Pradesh', 'Andhra Pradesh', 'Gujarat', 'Rajasthan',
#        'Karnataka', 'West Bengal', 'Telangana', 'Odisha', 'Maharashtra',
#        'Kerala', 'Bihar', 'Tamil Nadu', 'Madhya Pradesh', 'Assam',
#        'Tripura', 'Arunachal Pradesh', 'Punjab', 'Jharkhand', 'Delhi',
#        'Chandigarh', 'Chhattisgarh', 'Jammu and Kashmir', 'Mizoram',
#        'Nagaland', 'Himachal Pradesh', 'Goa', 'Haryana', 'Meghalaya',
#        'Uttarakhand', 'Manipur', 'Daman and Diu', 'Puducherry', 'Sikkim',
#        'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Dadra and Nagar Haveli', 'Orissa', 'Pondicherry',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'west Bengal', 'Daman & Diu', 'West  Bengal', 'odisha',
#        'Jammu & Kashmir', 'Lakshadweep', 'Dadra & Nagar Haveli',
#        'Westbengal', 'andhra pradesh', 'WEST BENGAL', 'West Bangal',
#        'West bengal', 'ODISHA', 'WESTBENGAL', 'Chhatisgarh',
# ...

# %%
df['state'] = df['state'].replace('Uttaranchal', 'Uttarakhand')
df['state'] = df['state'].replace('Tamilnadu', 'Tamil Nadu')

# %%
import pandas as pd
import re

def clean_state_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove symbols like &, .
    x = re.sub(r'\s+', ' ', x).strip()  # remove extra spaces
    return x

# %%
state_mapping = {
    # West Bengal
    'west bengal': 'West Bengal',
    'west bangal': 'West Bengal',
    'westbengal': 'West Bengal',
    'west  bengal': 'West Bengal',
    'westbengal ': 'West Bengal',
    'west bengli':  'West Bengal',
    

    # Andhra Pradesh
    'andhra pradesh': 'Andhra Pradesh',

    # Odisha
    'odisha': 'Odisha',
    'orissa': 'Odisha',

    # Jammu & Kashmir
    'jammu and kashmir': 'Jammu and Kashmir',
    'jammu kashmir': 'Jammu and Kashmir',

    # Collapse all Dadra / Daman variants into ONE state
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'the dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman diu': 'Dadra and Nagar Haveli and Daman and Diu',


    # Puducherry
    'puducherry': 'Puducherry',


    # Andaman & Nicobar Islands
    'andaman and nicobar islands': 'Andaman and Nicobar Islands',
    'andaman nicobar islands': 'Andaman and Nicobar Islands',

    # Puducherry
    'pondicherry': 'Puducherry',

    # Case-normalized direct matches
    'delhi': 'Delhi',
    'ladakh': 'Ladakh',
    'goa': 'Goa',
    'sikkim': 'Sikkim',
    'assam': 'Assam',
    'bihar': 'Bihar',
    'punjab': 'Punjab',
    'kerala': 'Kerala',
    'haryana': 'Haryana',
    'gujarat': 'Gujarat',
    'tamil nadu': 'Tamil Nadu',
    'telangana': 'Telangana',
    'karnataka': 'Karnataka',
    'maharashtra': 'Maharashtra',
    'Nagpur': 'Maharashtra',
    'rajasthan': 'Rajasthan',
    'uttar pradesh': 'Uttar Pradesh',
    'madhya pradesh': 'Madhya Pradesh',
    'himachal pradesh': 'Himachal Pradesh',
    'arunachal pradesh': 'Arunachal Pradesh',
    'chhattisgarh': 'Chhattisgarh',
    'chhatisgarh' : 'Chhattisgarh',
    'jharkhand': 'Jharkhand',
    'manipur': 'Manipur',
    'meghalaya': 'Meghalaya',
    'mizoram': 'Mizoram',
    'nagaland': 'Nagaland',
    'tripura': 'Tripura',
    'uttarakhand': 'Uttarakhand',
    'lakshadweep': 'Lakshadweep',
    'chandigarh': 'Chandigarh'
}

# %%
df['state_clean'] = (
    df['state']
    .apply(clean_state_name)
    .map(state_mapping)
)

# %%
# Drop invalid entries like numeric junk
df = df[~df['state'].astype(str).str.isnumeric()]

# Optional: check unmapped states
unmapped = df[df['state_clean'].isna()]['state'].unique()
print("Unmapped values:", unmapped)
# Out:
# Unmapped values: ['Darbhanga' 'Puttenahalli' 'BALANAGAR' 'Jaipur' 'Madanapalle' 'Nagpur'
#  'Raja Annamalai Puram']

# %%
df.tail(20)
# Out:
#                date        state                    district  pincode  \
# 2071680  29-12-2025  West Bengal  South Twenty Four Parganas   700070
# 2071681  29-12-2025  West Bengal  South Twenty Four Parganas   700140
# 2071682  29-12-2025  West Bengal  South Twenty Four Parganas   743318
# 2071683  29-12-2025  West Bengal  South Twenty Four Parganas   743347
# 2071684  29-12-2025  West Bengal  South Twenty Four Parganas   743374
# 2071685  29-12-2025  West Bengal  South Twenty Four Parganas   743377
# 2071686  29-12-2025  West Bengal              Uttar Dinajpur   733128
# 2071687  29-12-2025  West Bengal              Uttar Dinajpur   733150
# 2071688  29-12-2025  West Bengal              Uttar Dinajpur   733211
# 2071689  29-12-2025  West Bengal              Uttar Dinajpur   733212
# 2071690  29-12-2025  West Bengal              West Midnapore   721101
# 2071691  29-12-2025  West Bengal              West Midnapore   721102
# ...

# %%
df['state_clean'].unique()
# Out:
# array(['Uttar Pradesh', 'Andhra Pradesh', 'Gujarat', 'Rajasthan',
#        'Karnataka', 'West Bengal', 'Telangana', 'Odisha', 'Maharashtra',
#        'Kerala', 'Bihar', 'Tamil Nadu', 'Madhya Pradesh', 'Assam',
#        'Tripura', 'Arunachal Pradesh', 'Punjab', 'Jharkhand', 'Delhi',
#        'Chandigarh', 'Chhattisgarh', 'Jammu and Kashmir', 'Mizoram',
#        'Nagaland', 'Himachal Pradesh', 'Goa', 'Haryana', 'Meghalaya',
#        'Uttarakhand', 'Manipur',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Puducherry', 'Sikkim',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Lakshadweep', nan],
#       dtype=object)

# %%
df['state_clean'].nunique()
# Out:
# 36

# %%
df.dtypes
# Out:
# date             object
# state            object
# district         object
# pincode           int64
# demo_age_5_17     int64
# demo_age_17_      int64
# new_date         object
# state_clean      object
# dtype: object

# %%
df
# Out:
#                date           state        district  pincode  demo_age_5_17  \
# 0        01-03-2025   Uttar Pradesh       Gorakhpur   273213             49
# 1        01-03-2025  Andhra Pradesh        Chittoor   517132             22
# 2        01-03-2025         Gujarat          Rajkot   360006             65
# 3        01-03-2025  Andhra Pradesh      Srikakulam   532484             24
# 4        01-03-2025       Rajasthan         Udaipur   313801             45
# ...             ...             ...             ...      ...            ...
# 2071695  29-12-2025     West Bengal  West Midnapore   721212              0
# 2071696  29-12-2025     West Bengal  West Midnapore   721420              0
# 2071697  29-12-2025     West Bengal  West Midnapore   721424              0
# 2071698  29-12-2025     West Bengal  West Midnapore   721426              0
# 2071699  29-12-2025     West Bengal         hooghly   712701              0
#
#          demo_age_17_    new_date     state_clean
# ...

# %%
df_odisha=df[df['state_clean']=='Odisha']
df_odisha
# Out:
#                date   state      district  pincode  demo_age_5_17  \
# 14       01-03-2025  Odisha      Nayagarh   752081             48
# 31       01-03-2025  Odisha  Nabarangapur   764077             37
# 63       01-03-2025  Odisha       Koraput   764039             42
# 93       01-03-2025  Odisha        Ganjam   761012             54
# 134      01-03-2025  Odisha       Koraput   764056             93
# ...             ...     ...           ...      ...            ...
# 2065286  28-12-2025  Orissa      Nayagarh   752070              0
# 2065287  28-12-2025  Orissa          Puri   752014              0
# 2065288  28-12-2025  Orissa      Rayagada   765001              0
# 2065289  28-12-2025  Orissa     Sambalpur   768017              1
# 2065290  28-12-2025  Orissa    Sundargarh   770033              0
#
#          demo_age_17_    new_date state_clean
# 14                295  2025 03 01      Odisha
# 31                465  2025 03 01      Odisha
# ...

# %%
df_odisha['district'].unique()
# Out:
# array(['Nayagarh', 'Nabarangapur', 'Koraput', 'Ganjam', 'Mayurbhanj',
#        'Sambalpur', 'Kendrapara', 'Kendujhar', 'Bhadrak', 'JAJPUR',
#        'Jajapur', 'Baleswar', 'Dhenkanal', 'Puri', 'Khorda', 'Gajapati',
#        'Angul', 'Nuapada', 'Baleshwar', 'Cuttack', 'Boudh',
#        'Jagatsinghapur', 'Balangir', 'Jharsuguda', 'Kalahandi',
#        'Sundergarh', 'Rayagada', 'Debagarh', 'Sonapur', 'Bargarh',
#        'Malkangiri', 'Kandhamal', 'Anugul', 'Baudh', 'Jagatsinghpur',
#        'Khordha', 'Sundargarh', 'Subarnapur', 'Jajpur', 'jajpur',
#        'NUAPADA', 'Jajapur  *', 'ANUGUL', 'ANGUL', 'Balianta', 'Anugal',
#        'Bhadrak(R)'], dtype=object)

# %%
import re
import pandas as pd

def clean_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove (), ., etc
    x = re.sub(r'\s+', ' ', x).strip()
    return x

# %%
district_mapping_odisha = {

    # Angul
    'angul': 'Angul',
    'anugul': 'Angul',
    'anugal': 'Angul',
    'anugul ': 'Angul',
    'anugul*': 'Angul',
    'anugul  *': 'Angul',

    # Balangir
    'balangir': 'Balangir',
    'bolangir': 'Balangir',

    # Baleswar (Balasore)
    'baleswar': 'Baleswar',
    'baleshwar': 'Baleswar',
    'balasore': 'Baleswar',

    # Bargarh
    'bargarh': 'Bargarh',

    # Bhadrak
    'bhadrak': 'Bhadrak',

    # Boudh
    'boudh': 'Boudh',
    'baudh': 'Boudh',

    # Cuttack
    'cuttack': 'Cuttack',

    # Debagarh
    'debagarh': 'Debagarh',
    'deogarh': 'Debagarh',

    # Dhenkanal
    'dhenkanal': 'Dhenkanal',

    # Gajapati
    'gajapati': 'Gajapati',

    # Ganjam
    'ganjam': 'Ganjam',

    # Jagatsinghapur
    'jagatsinghapur': 'Jagatsinghapur',
    'jagatsinghpur': 'Jagatsinghapur',

    # Jajpur
    'jajapur': 'Jajpur',
    'jajpur': 'Jajpur',
    'jajpur ': 'Jajpur',

    # Jharsuguda
    'jharsuguda': 'Jharsuguda',

    # Kalahandi
    'kalahandi': 'Kalahandi',

    # Kandhamal
    'kandhamal': 'Kandhamal',
    'phulbani': 'Kandhamal',

    # Kendrapara
    'kendrapara': 'Kendrapara',

    # Kendujhar (Keonjhar)
    'kendujhar': 'Kendujhar',
    'keonjhar': 'Kendujhar',

    # Khordha
    'khorda': 'Khordha',
    'khordha': 'Khordha',
    'khordha  *': 'Khordha',

    # Koraput
    'koraput': 'Koraput',

    # Malkangiri
    'malkangiri': 'Malkangiri',

    # Mayurbhanj
    'mayurbhanj': 'Mayurbhanj',

    # Nabarangapur
    'nabarangapur': 'Nabarangapur',
    'nabarangpur': 'Nabarangapur',

    # Nayagarh
    'nayagarh': 'Nayagarh',

    # Nuapada
    'nuapada': 'Nuapada',

    # Puri
    'puri': 'Puri',

    # Rayagada
    'rayagada': 'Rayagada',

    # Sambalpur
    'sambalpur': 'Sambalpur',

    # Subarnapur (Sonapur)
    'sonapur': 'Subarnapur',
    'subarnapur': 'Subarnapur',

    # Sundargarh
    'sundergarh': 'Sundargarh',
    'sundargarh': 'Sundargarh',
}

# %%
df_odisha = df_odisha.copy()

# %%
df_odisha.loc[:, 'district_clean'] = (
    df_odisha['district']
    .apply(clean_name)
    .map(district_mapping_odisha)
    .fillna(df_odisha['district'])
)

# %%
df_odisha
# Out:
#                date   state      district  pincode  demo_age_5_17  \
# 14       01-03-2025  Odisha      Nayagarh   752081             48
# 31       01-03-2025  Odisha  Nabarangapur   764077             37
# 63       01-03-2025  Odisha       Koraput   764039             42
# 93       01-03-2025  Odisha        Ganjam   761012             54
# 134      01-03-2025  Odisha       Koraput   764056             93
# ...             ...     ...           ...      ...            ...
# 2065286  28-12-2025  Orissa      Nayagarh   752070              0
# 2065287  28-12-2025  Orissa          Puri   752014              0
# 2065288  28-12-2025  Orissa      Rayagada   765001              0
# 2065289  28-12-2025  Orissa     Sambalpur   768017              1
# 2065290  28-12-2025  Orissa    Sundargarh   770033              0
#
#          demo_age_17_    new_date state_clean district_clean
# 14                295  2025 03 01      Odisha       Nayagarh
# ...

# %%
pin_district_count = (
    df_odisha.groupby('pincode')['district_clean']
      .nunique()
      .reset_index(name='district_count')
)

# %%
pin_district_count
# Out:
#      pincode  district_count
# 0     751001               1
# 1     751002               2
# 2     751003               1
# 3     751004               1
# 4     751005               1
# ..       ...             ...
# 933   770072               1
# 934   770073               1
# 935   770074               1
# 936   770075               1
# 937   770076               1
#
# [938 rows x 2 columns]

# %%
problem_pins = pin_district_count[
    pin_district_count['district_count'] > 1
]

# %%
problem_pins
# Out:
#      pincode  district_count
# 1     751002               2
# 29    752001               2
# 36    752015               2
# 38    752017               2
# 40    752019               2
# ..       ...             ...
# 871   768221               3
# 872   768222               2
# 873   768224               2
# 875   768226               2
# 877   768228               3
#
# [156 rows x 2 columns]

# %%
df_flagged = df_odisha.merge(
    problem_pins[['pincode']],
    on='pincode',
    how='inner'
)

# %%
df_flagged
# Out:
#              date   state    district  pincode  demo_age_5_17  demo_age_17_  \
# 0      01-03-2025  Odisha    Nayagarh   752081             48           295
# 1      01-03-2025  Odisha  Kendrapara   754208             22           227
# 2      01-03-2025  Odisha      Ganjam   761014             36           307
# 3      01-03-2025  Odisha   Sambalpur   768221             42           231
# 4      01-03-2025  Odisha     Bhadrak   756123             43           199
# ...           ...     ...         ...      ...            ...           ...
# 23608  28-12-2025  Odisha     Sonapur   767068              1             2
# 23609  28-12-2025  Orissa   Baleshwar   756028              0             0
# 23610  28-12-2025  Orissa     Bhadrak   756133              0             1
# 23611  28-12-2025  Orissa      Ganjam   761003              0             1
# 23612  28-12-2025  Orissa     Khordha   754001              0             1
#
#          new_date state_clean district_clean
# ...

# %%
df_odisha_cleaned=df_odisha.drop(columns=['date','district','state'], axis=1)
df_odisha_cleaned
# Out:
#          pincode  demo_age_5_17  demo_age_17_    new_date state_clean  \
# 14        752081             48           295  2025 03 01      Odisha
# 31        764077             37           465  2025 03 01      Odisha
# 63        764039             42           432  2025 03 01      Odisha
# 93        761012             54           422  2025 03 01      Odisha
# 134       764056             93           779  2025 03 01      Odisha
# ...          ...            ...           ...         ...         ...
# 2065286   752070              0             1  2025 12 28      Odisha
# 2065287   752014              0             1  2025 12 28      Odisha
# 2065288   765001              0             2  2025 12 28      Odisha
# 2065289   768017              1             1  2025 12 28      Odisha
# 2065290   770033              0             2  2025 12 28      Odisha
#
#         district_clean
# 14            Nayagarh
# 31        Nabarangapur
# 63             Koraput
# 93              Ganjam
# ...

# %%
df_odisha['total_enroll']=df_odisha['demo_age_5_17']+df_odisha['demo_age_17_']
df_odisha
# Out:
#                date   state      district  pincode  demo_age_5_17  \
# 14       01-03-2025  Odisha      Nayagarh   752081             48
# 31       01-03-2025  Odisha  Nabarangapur   764077             37
# 63       01-03-2025  Odisha       Koraput   764039             42
# 93       01-03-2025  Odisha        Ganjam   761012             54
# 134      01-03-2025  Odisha       Koraput   764056             93
# ...             ...     ...           ...      ...            ...
# 2065286  28-12-2025  Orissa      Nayagarh   752070              0
# 2065287  28-12-2025  Orissa          Puri   752014              0
# 2065288  28-12-2025  Orissa      Rayagada   765001              0
# 2065289  28-12-2025  Orissa     Sambalpur   768017              1
# 2065290  28-12-2025  Orissa    Sundargarh   770033              0
#
#          demo_age_17_    new_date state_clean district_clean  total_enroll
# 14                295  2025 03 01      Odisha       Nayagarh           343
# ...

# %%
df_odisha['month']=df_odisha['new_date'].astype(str).str[4:6]
df_odisha
# Out:
#                date   state      district  pincode  demo_age_5_17  \
# 14       01-03-2025  Odisha      Nayagarh   752081             48
# 31       01-03-2025  Odisha  Nabarangapur   764077             37
# 63       01-03-2025  Odisha       Koraput   764039             42
# 93       01-03-2025  Odisha        Ganjam   761012             54
# 134      01-03-2025  Odisha       Koraput   764056             93
# ...             ...     ...           ...      ...            ...
# 2065286  28-12-2025  Orissa      Nayagarh   752070              0
# 2065287  28-12-2025  Orissa          Puri   752014              0
# 2065288  28-12-2025  Orissa      Rayagada   765001              0
# 2065289  28-12-2025  Orissa     Sambalpur   768017              1
# 2065290  28-12-2025  Orissa    Sundargarh   770033              0
#
#          demo_age_17_    new_date state_clean district_clean  total_enroll  \
# 14                295  2025 03 01      Odisha       Nayagarh           343
# ...

# %%
df_odisha_cleaned=df_odisha.drop(columns=['date','district','state'], axis=1)
df_odisha_cleaned
# Out:
#          pincode  demo_age_5_17  demo_age_17_    new_date state_clean  \
# 14        752081             48           295  2025 03 01      Odisha
# 31        764077             37           465  2025 03 01      Odisha
# 63        764039             42           432  2025 03 01      Odisha
# 93        761012             54           422  2025 03 01      Odisha
# 134       764056             93           779  2025 03 01      Odisha
# ...          ...            ...           ...         ...         ...
# 2065286   752070              0             1  2025 12 28      Odisha
# 2065287   752014              0             1  2025 12 28      Odisha
# 2065288   765001              0             2  2025 12 28      Odisha
# 2065289   768017              1             1  2025 12 28      Odisha
# 2065290   770033              0             2  2025 12 28      Odisha
#
#         district_clean  total_enroll month
# 14            Nayagarh           343     0
# ...

# %%
df_odisha_dist_level=df_odisha_cleaned.groupby('district_clean')[['demo_age_5_17','demo_age_17_','total_enroll']].sum()
df_odisha_dist_level.shape
# Out:
# (32, 3)

# %%
df_odisha_dist_level
# Out:
#                 demo_age_5_17  demo_age_17_  total_enroll
# district_clean
# Angul                    4102         27189         31291
# Balangir                 5240         37354         42594
# Baleswar                 9035         46466         55501
# Balianta                    0             1             1
# Bargarh                  4584         30887         35471
# Bhadrak                  7114         35536         42650
# Bhadrak(R)                  0             1             1
# Boudh                    1411          8906         10317
# Cuttack                  5928         44743         50671
# Debagarh                 1020          6969          7989
# Dhenkanal                4482         25501         29983
# Gajapati                 3255         18133         21388
# Ganjam                  12890         85949         98839
# Jagatsinghapur           2732         18130         20862
# Jajpur                   6478         39229         45707
# ...

# %%
df_odisha_dist_level=df_odisha_dist_level.sort_values('total_enroll', ascending=False).reset_index()

# %%
df_odisha_dist_level1=df_odisha_dist_level.head(10)
df_odisha_dist_level1
# Out:
#   district_clean  demo_age_5_17  demo_age_17_  total_enroll
# 0         Ganjam          12890         85949         98839
# 1     Mayurbhanj           9770         61751         71521
# 2       Baleswar           9035         46466         55501
# 3      Kendujhar           7205         47233         54438
# 4        Cuttack           5928         44743         50671
# 5     Sundargarh           5940         44396         50336
# 6      Kalahandi           5491         41904         47395
# 7        Khordha           6108         40146         46254
# 8         Jajpur           6478         39229         45707
# 9        Bhadrak           7114         35536         42650

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_odisha_dist_level1[['demo_age_5_17','demo_age_17_']])
plt.show()

# %%
df_odisha_pincode_level=df_odisha_cleaned.groupby('pincode')[['demo_age_5_17','demo_age_17_','total_enroll']].sum()
df_odisha_pincode_level.shape
# Out:
# (938, 3)

# %%
df_odisha_pincode_level.sort_values('total_enroll', ascending=False).reset_index()
# Out:
#      pincode  demo_age_5_17  demo_age_17_  total_enroll
# 0     765015            689          6404          7093
# 1     764076            590          6263          6853
# 2     762002            829          4790          5619
# 3     764072            594          4898          5492
# 4     767025            740          4629          5369
# ..       ...            ...           ...           ...
# 933   754118              0             1             1
# 934   759135              0             1             1
# 935   755062              0             1             1
# 936   755041              0             1             1
# 937   759029              0             1             1
#
# [938 rows x 4 columns]

# %%
df_odisha_pincode_level=df_odisha_pincode_level.sort_values('total_enroll', ascending=False).reset_index()

# %%
df_odisha_pincode_level1=df_odisha_pincode_level.head(10)
df_odisha_pincode_level1
# Out:
#    pincode  demo_age_5_17  demo_age_17_  total_enroll
# 0   765015            689          6404          7093
# 1   764076            590          6263          6853
# 2   762002            829          4790          5619
# 3   764072            594          4898          5492
# 4   767025            740          4629          5369
# 5   764073            581          4694          5275
# 6   762011            781          3816          4597
# 7   764074            402          3973          4375
# 8   764043            588          3749          4337
# 9   767018            848          3449          4297

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_odisha_pincode_level1[['demo_age_5_17','demo_age_17_','total_enroll']])
plt.show()

# %%
odisha_month_enroll_trend=df_odisha_cleaned.groupby('month')[['demo_age_5_17','demo_age_17_','total_enroll']].sum()
odisha_month_enroll_trend
# Out:
#        demo_age_5_17  demo_age_17_  total_enroll
# month
# 0              61999        514812        576811
# 1              85500        449754        535254

# %%
sns.lineplot(data=odisha_month_enroll_trend)
# Out:
# <Axes: xlabel='month'>
